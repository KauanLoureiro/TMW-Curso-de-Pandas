# %%
import pandas as pd

# %%
df_transact = pd.read_csv("../DB/transacoes.csv", sep=";")

# %%
# Qt de pontos igual a 1 ou 100 em 2025

filtro1 = ((df_transact['QtdePontos'] == 1) | (df_transact['QtdePontos'] == 100))&(df_transact['DtCriacao'] >='2025-01-01')

df_transact[filtro1].sort_values("DtCriacao", ascending=0)
# Out:
#                                  IdTransacao  \
# 27699   1c06e833-ead2-4d56-b1b5-ca2032f36dd4
# 162000  a59552d9-284e-4854-b0d2-818cd9dfb0f6
# 99090   6588da4d-149b-4390-a278-65326c49e6c9
# 10662   0adf2aaf-dc83-46dc-b186-cc7fa3c86f6a
# 196513  c8d7b359-40e5-4906-a42a-5469b11aba4a
# ...                                      ...
# 134864  8a0d8176-e2dd-4fc0-a53d-803c68a6428c
# 141829  912c061e-d3f4-48ea-af24-8a4d67b3cef1
# 84406   568a7d69-65ef-4be5-acfe-41ee7ec4825e
# 206891  d377e603-afb8-4ec8-9755-acdc8e5e9316
# 169157  acea1a73-751f-4057-8516-9cc508a12eba
#
#                                    IdCliente                DtCriacao  \
# 27699   a6e4050d-a9e0-4fcc-9022-b1d4d849f16f  2025-10-02 14:18:34.879
# 162000  70845f41-0fdb-4f8f-910b-5b3ac34fb562  2025-10-02 14:18:04.669
# 99090   c609fb20-e579-4e83-a4b1-c38a66632d60  2025-10-02 14:18:01.260
# 10662   564ab6da-2ad3-4c5f-9e59-60de8d89fbcc  2025-10-02 14:17:58.724
# ...

# %%
# Qt de pontos diferente de 100

filtro2 = ~(df_transact['QtdePontos'] == 100)
df_transact[filtro2]
# Out:
#                                  IdTransacao  \
# 0       0000520a-a4e5-4977-b360-17be62fa0f2b
# 1       000060e8-aa76-4286-a8d7-f30e6fa47edd
# 2       000095de-3daa-4cfb-a0ae-e7b2c8bc3c9b
# 3       0000dfbb-e14e-4ea7-a57f-60236869fffe
# 4       0000e94f-fb76-42b7-82e3-5059b6e40703
# ...                                      ...
# 250390  ffff45c7-83dc-4fa9-82b5-b41352093596
# 250391  ffff52de-13fb-4405-a797-fddb5b4a48c5
# 250392  ffffb5ab-047e-43e4-bab3-ee2d19e9b7db
# 250393  ffffc72e-d882-47f0-b933-cfd92c7e6621
# 250394  fffff928-9a18-4741-a516-3a92351d1d72
#
#                                    IdCliente                DtCriacao  \
# 0       24782f0b-4683-4f35-976a-ea21d6714ba6  2025-09-17 12:28:41.864
# 1       252a0923-3f79-45bb-b664-3040235c6c58  2024-07-23 12:49:49.874
# 2       30f45a6d-ada5-4a17-8338-710e414eb6c6  2025-09-17 13:38:57.479
# 3       5f8fcbe0-6014-43f8-8b83-38cf2f4887b3  2024-02-20 13:21:45.613
# ...

# %%
df_clientes = pd.read_csv(r"C:\Users\kauan\Desktop\projeto\TEO ME WHY\Aula pandas TMW\DB\clientes.csv", sep=";")

# %%
filtro4 = ~(df_clientes["qtdePontos"] == 0)
clientesnot0pts = df_clientes.loc[filtro4].copy()
clientesnot0pts['Amoca'] = 1
clientesnot0pts
# Out:
#                                  idCliente  flEmail  flTwitch  flYouTube  \
# 0     000ff655-fa9f-4baa-a108-47f581ec52a1        0         0          0
# 1     001749bd-37b5-4b1e-8111-f9fbba90f530        0         0          0
# 2     0019bb9e-26d4-4ebf-8727-fc911ea28a92        0         0          0
# 4     0033b737-8235-4c0f-9801-dc4ca185af00        0         1          0
# 6     0068860b-c7eb-4312-830d-4ab9273c9b15        0         1          0
# ...                                    ...      ...       ...        ...
# 3981  ff07d926-f09e-420b-bebf-3dba02ae5dff        0         1          0
# 3982  ff1ceaef-650c-422b-bdc3-6984e29e7aa5        0         0          0
# 3983  ff2cabd3-3316-4b3f-8494-c25f95e90524        0         1          0
# 3984  ff4909ad-4e52-4767-a6fc-0fbd76e37857        0         0          0
# 3985  ff5d2399-6b53-49f0-b41e-fdaaa0da172a        0         1          0
#
#       flBlueSky  flInstagram  qtdePontos                DtCriacao  \
# ...

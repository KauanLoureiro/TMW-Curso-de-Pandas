# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\kauan\Desktop\projeto\TEO ME WHY\Aula pandas TMW\DB\Lifestyle_and_Health_Risk_Prediction_Synthetic_Dataset.csv")

# %%
df.describe()
# Out:
#                age       weight       height        sleep         bmi
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.00000
# mean     48.805600    77.359200   171.933200     6.997060    26.84388
# std      17.906991    18.714567    15.822225     1.432849     8.25249
# min      18.000000    45.000000   145.000000     3.000000    11.40000
# 25%      34.000000    61.000000   158.000000     6.000000    20.30000
# 50%      49.000000    77.000000   171.500000     7.000000    26.00000
# 75%      64.000000    94.000000   186.000000     8.000000    32.40000
# max      79.000000   109.000000   199.000000    10.000000    51.40000

# %%
df.loc[25]
# Out:
# age                        47
# weight                     62
# height                    177
# exercise                  low
# sleep                     7.4
# sugar_intake              low
# smoking                    no
# alcohol                    no
# married                   yes
# profession      office_worker
# bmi                      19.8
# health_risk               low
# Name: 25, dtype: object

# %%
age_weight_index = df.set_index("weight")["age"]

# %%
age.iloc[0]
# Out:
# np.int64(56)

# %%
age_sorted = age.sort_values()

# %%
print(f"A idade do primeiro da lista é {age_sorted.loc[0]}, a idade do mais novo é {age_sorted.iloc[0]} e a do mais velho é {age_sorted.iloc[-1]}")
# Out:
# A idade do primeiro da lista é 56, a idade do mais novo é 18 e a do mais velho é 79

# %%
teste = pd.DataFrame()

# %%
teste["Peso"] = df["weight"]
teste["idade"] = df["age"]

# %%
peso_da_pessoa_mais_velha = teste.sort_values(by="idade", ascending=0).iloc[0]["Peso"]

# %%
df.sort_values(by="age", ascending=0).iloc[0]["weight"]
# Out:
# np.int64(98)

# %%
print(f"O peso da pessoa mais velha é {peso_da_pessoa_mais_velha} kg")
# Out:
# O peso da pessoa mais velha é 98 kg

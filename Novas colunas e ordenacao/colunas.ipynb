# %%
import pandas as pd

# %%
df_clientes = pd.read_csv(r"C:\Users\kauan\Desktop\projeto\TEO ME WHY\Aula pandas TMW\DB\clientes.csv", sep=';')

# %%
df_clientes
# Out:
#                                  idCliente  flEmail  flTwitch  flYouTube  \
# 0     000ff655-fa9f-4baa-a108-47f581ec52a1        0         0          0
# 1     001749bd-37b5-4b1e-8111-f9fbba90f530        0         0          0
# 2     0019bb9e-26d4-4ebf-8727-fc911ea28a92        0         0          0
# 3     002970bd-65c2-42bf-a17d-2bc5e95e2f0b        0         1          0
# 4     0033b737-8235-4c0f-9801-dc4ca185af00        0         1          0
# ...                                    ...      ...       ...        ...
# 3982  ff1ceaef-650c-422b-bdc3-6984e29e7aa5        0         0          0
# 3983  ff2cabd3-3316-4b3f-8494-c25f95e90524        0         1          0
# 3984  ff4909ad-4e52-4767-a6fc-0fbd76e37857        0         0          0
# 3985  ff5d2399-6b53-49f0-b41e-fdaaa0da172a        0         1          0
# 3986  ff8d55dc-64fa-40de-992a-04a4155f5634        0         1          0
#
#       flBlueSky  flInstagram  qtdePontos                DtCriacao  \
# ...

# %%
#Quantas contas cadastradas cada pessoa tem ? E quem tem mais de uma conta?
df_clientes["Tot_cont"] = df_clientes["flEmail"] + df_clientes["flTwitch"] + df_clientes["flYouTube"] + df_clientes["flBlueSky"] + df_clientes["flInstagram"]


filtro = df_clientes["Tot_cont"] >= 2
df_clientes[filtro]

# %%
import numpy as np

# %%
#Aplicando ln na coluna quantidade de pontos

np.log(df_clientes["qtdePontos"])
# Out:
# c:\Users\kauan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0       10.130065
# 1        3.912023
# 2        0.693147
# 3            -inf
# 4        7.848153
#           ...
# 3982     5.087596
# 3983     4.043051
# 3984     3.912023
# 3985     6.587550
# 3986         -inf
# Name: qtdePontos, Length: 3987, dtype: float64

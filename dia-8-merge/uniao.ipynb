# %%
import pandas as pd

transacoes = pd.read_csv("../DB/transacoes.csv", sep=";")

transacoes.head()
# Out:
#                             IdTransacao                             IdCliente  \
# 0  0000520a-a4e5-4977-b360-17be62fa0f2b  24782f0b-4683-4f35-976a-ea21d6714ba6
# 1  000060e8-aa76-4286-a8d7-f30e6fa47edd  252a0923-3f79-45bb-b664-3040235c6c58
# 2  000095de-3daa-4cfb-a0ae-e7b2c8bc3c9b  30f45a6d-ada5-4a17-8338-710e414eb6c6
# 3  0000dfbb-e14e-4ea7-a57f-60236869fffe  5f8fcbe0-6014-43f8-8b83-38cf2f4887b3
# 4  0000e94f-fb76-42b7-82e3-5059b6e40703  3884c92f-a635-4b67-9e5a-97730829cdca
#
#                  DtCriacao  QtdePontos DescSistemaOrigem
# 0  2025-09-17 12:28:41.864           1            twitch
# 1  2024-07-23 12:49:49.874           1            twitch
# 2  2025-09-17 13:38:57.479           1            twitch
# 3  2024-02-20 13:21:45.613           1            twitch
# 4  2024-02-05 13:27:18.987           1            twitch

# %%
clientes = pd.read_csv("../DB/clientes.csv", sep=";")

clientes.columns = ["IdCliente", "flEmail", "flTwitch", "flYouTube", "flBlueSky", "flInstagram", "qtdePontos", "DtCriacao", "DtAtualizacao"]

clientes.head()
# Out:
#                               IdCliente  flEmail  flTwitch  flYouTube  \
# 0  000ff655-fa9f-4baa-a108-47f581ec52a1        0         0          0
# 1  001749bd-37b5-4b1e-8111-f9fbba90f530        0         0          0
# 2  0019bb9e-26d4-4ebf-8727-fc911ea28a92        0         0          0
# 3  002970bd-65c2-42bf-a17d-2bc5e95e2f0b        0         1          0
# 4  0033b737-8235-4c0f-9801-dc4ca185af00        0         1          0
#
#    flBlueSky  flInstagram  qtdePontos                DtCriacao  \
# 0          0            0       25086  2024-02-01 00:00:00.000
# 1          0            0          50  2024-02-01 00:00:00.000
# 2          0            0           2  2024-02-01 00:00:00.000
# 3          0            0           0  2025-07-16 09:36:45.831
# 4          0            0        2561  2025-02-19 12:48:24.632
#
#              DtAtualizacao
# 0  2025-09-26 13:28:37.697
# 1  2024-02-01 00:00:00.000
# 2  2024-02-01 00:00:00.000
# 3  2025-07-16 09:36:45.831
# ...

# %%
transacoes.merge(right=clientes, how="left", on=["IdCliente"], suffixes=["_transacao", "_clientes"])
# Out:
#                                  IdTransacao  \
# 0       0000520a-a4e5-4977-b360-17be62fa0f2b
# 1       000060e8-aa76-4286-a8d7-f30e6fa47edd
# 2       000095de-3daa-4cfb-a0ae-e7b2c8bc3c9b
# 3       0000dfbb-e14e-4ea7-a57f-60236869fffe
# 4       0000e94f-fb76-42b7-82e3-5059b6e40703
# ...                                      ...
# 250390  ffff45c7-83dc-4fa9-82b5-b41352093596
# 250391  ffff52de-13fb-4405-a797-fddb5b4a48c5
# 250392  ffffb5ab-047e-43e4-bab3-ee2d19e9b7db
# 250393  ffffc72e-d882-47f0-b933-cfd92c7e6621
# 250394  fffff928-9a18-4741-a516-3a92351d1d72
#
#                                    IdCliente      DtCriacao_transacao  \
# 0       24782f0b-4683-4f35-976a-ea21d6714ba6  2025-09-17 12:28:41.864
# 1       252a0923-3f79-45bb-b664-3040235c6c58  2024-07-23 12:49:49.874
# 2       30f45a6d-ada5-4a17-8338-710e414eb6c6  2025-09-17 13:38:57.479
# 3       5f8fcbe0-6014-43f8-8b83-38cf2f4887b3  2024-02-20 13:21:45.613
# ...
